# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#load dataset
import os
print(os.getcwd())
data = pd.read_csv("../data/data.csv")
# Out:
# /home/katrist/Projects/DataByte/India-data-visualisation/engineers-employability/scripts

# %%
sns.catplot(x="CollegeTier", y="Salary", kind="bar", data=data[data['collegeGPA']>70]);
